# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "***Clustering (Customer Segmentation) Project***". This is the last medium project of ***Machine Learning*** course.
#
# At the end of this project, you will have performed ***Cluster Analysis*** with an ***Unsupervised Learning*** method.
#
# ---
#
# In this project, customers are required to be segmented according to the purchasing history obtained from the membership cards of a big mall.
#
# This project is less challenging than other projects. After getting to know the data set quickly, you are expected to perform ***Exploratory Data Analysis***. You should observe the distribution of customers according to different variables, also discover relationships and correlations between variables. Then you will spesify the different variables to use for cluster analysis.
#
# Finally, you should clustered customers using the ***K-Means Clustering*** method, after that label the clusters.
#
# - ***NOTE:*** *This project assumes that you already know the basics of coding in Python. You should also be familiar with the theory behind Cluster Analysis and scikit-learn module as well as Machine Learning before you begin.*

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Tasks

# %% [markdown]
# Mentoring Prep. and self study####
#
# #### 1. Import Libraries, Load Dataset, Exploring Data
# - Import Libraries
# - Load Dataset
# - Explore Data
#
# #### 2. Exploratory Data Analysis (EDA)
#
#
# #### 3. Cluster Analysis
#
# - Clustering based on Age and Spending Score
#
#     *i. Create a new dataset with two variables of your choice*
#
#     *ii. Determine optimal number of clusters*
#
#     *iii. Apply K Means*
#
#     *iv. Visualizing and Labeling All the Clusters*
#
#
# - Clustering based on Annual Income and Spending Score
#
#     *i. Create a new dataset with two variables of your choice*
#
#     *ii. Determine optimal number of clusters*
#
#     *iii. Apply K Means*
#
#     *iv. Visualizing and Labeling All the Clusters*
#
#
# - Hierarchical Clustering
#
#     *i. Determine optimal number of clusters using Dendogram*
#
#     *ii. Apply Agglomerative Clustering*
#
#     *iii. Visualizing and Labeling All the Clusters*
#
# - Conclusion

# %% [markdown]
# ---
# ---

# %% [markdown]
# # 1. Import Libraries, Load Dataset, Exploring Data
#
# There is a big mall in a specific city that keeps information of its customers who subscribe to a membership card. In the membetrship card they provide following information : gender, age and annula income. The customers use this membership card to make all the purchases in the mall, so tha mall has the purchase history of all subscribed members and according to that they compute the spending score of all customers. You have to segment these customers based on the details given.

# %% [markdown]
# ## Import Libraries

# %%
# !pip install ipython

# %%
#!pip uninstall ipython

# %%
#!pip install pyforest
#!pip install ipython
# 1-Import Libraies

import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline
# %matplotlib notebook
import statsmodels.api as sm
import statsmodels.formula.api as smf


from sklearn.compose import make_column_transformer

#Scaling
from sklearn.preprocessing import scale 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler


#Importing plotly and cufflinks in offline mode
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

#Ignore Warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

#Figure&Display options
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('max_colwidth',200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

#!pip install termcolor
from termcolor import colored
import missingno as msno 

# !pip3 install termcolor
import colorama
from colorama import Fore, Style  # maakes strings colored
from termcolor import colored
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
## Useful Functions

###############################################################################

def missing(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values

def missing_values(df):
    return missing(df)[missing(df)['Missing_Number']>0]

###############################################################################

def first_looking(df):
    print(colored("Shape:", attrs=['bold']), df.shape,'\n',
          f"There is ", df.shape[0], " observation and ", df.shape[1], " columns in the dataset.", '\n',
          colored('-'*79, 'red', attrs=['bold']),
          colored("\nInfo:\n", attrs=['bold']), sep='')
    print(df.info(), '\n', 
          colored('-'*79, 'red', attrs=['bold']), sep='')
    print(colored("Number of Uniques:\n", attrs=['bold']), df.nunique(),'\n',
          colored('-'*79, 'red', attrs=['bold']), sep='')
    print(colored("Missing Values:\n", attrs=['bold']), missing_values(df),'\n', 
          colored('-'*79, 'red', attrs=['bold']), sep='')
    print(colored("All Columns:", attrs=['bold']), list(df.columns),'\n', 
          colored('-'*79, 'red', attrs=['bold']), sep='')

    df.columns= df.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

    print(colored("Columns after rename:", attrs=['bold']), list(df.columns),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')

def duplicate_values(df):
    duplicate_values = df.duplicated(subset=None, keep='first').sum()
    if duplicate_values > 0:
        df.drop_duplicates(keep='first', inplace=True)
        print(duplicate_values, colored("duplicates were dropped", attrs=['bold']),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')
    else:
        print(colored("No duplicates", attrs=['bold']),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')
        
def drop_columns(df, drop_columns):
    if drop_columns !=[]:
        df.drop(drop_columns, axis=1, inplace=True)
        print(drop_columns, 'were dropped')
    else:
        print(colored('We will now check the missing values and if necessary drop some columns!!!', attrs=['bold']),'\n',
              colored('-'*79, 'red', attrs=['bold']), sep='')
        
def drop_null(df, limit):
    print('Shape:', df.shape)
    for i in df.isnull().sum().index:
        if (df.isnull().sum()[i]/df.shape[0]*100)>limit:
            print(df.isnull().sum()[i], 'percent of', i ,'null and were dropped')
            df.drop(i, axis=1, inplace=True)
            print('new shape:', df.shape)
        else:
            print(df.isnull().sum()[i], '%, percentage of missing values of', i ,'less than limit', limit, '%, so we will keep it.')
    print('New shape after missing value control:', df.shape)

###############################################################################

# %% [markdown]
# ## Load Dataset | Explore Data

# %%
# 2-Load|Read Data
with pd.option_context('display.max_columns', None):
    dataset_path = "Mall_Customers.csv"
    df0 = pd.read_csv(dataset_path)
    df = df0.copy() 
    first_looking(df)
    duplicate_values(df)
    drop_columns(df,[])
    drop_null(df, 90)
    # df.head()
    # df.tail()
    # df.sample(5)
    # df.describe().T
    # df.describe(include=object).T
# Out:
# Shape:(200, 5)
# There is 200 observation and 5 columns in the dataset.
# -------------------------------------------------------------------------------
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None
# -------------------------------------------------------------------------------
# Number of Uniques:
# CustomerID                200
# Gender                      2
# Age                        51
# Annual Income (k$)         64
# Spending Score (1-100)     84
# dtype: int64
# -------------------------------------------------------------------------------
# Missing Values:
# Empty DataFrame
# Columns: [Missing_Number, Missing_Percent]
# Index: []
# -------------------------------------------------------------------------------
# All Columns:['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']
# -------------------------------------------------------------------------------
# Columns after rename:['customerid', 'gender', 'age', 'annual_income_(k$)', 'spending_score_(1-100)']
# -------------------------------------------------------------------------------
# No duplicates
# -------------------------------------------------------------------------------
# We will now check the missing values and if necessary drop some columns!!!
# -------------------------------------------------------------------------------
# Shape: (200, 5)
# 0 %, percentage of missing values of customerid less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of gender less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of age less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of annual_income_(k$) less than limit 90 %, so we will keep it.
# 0 %, percentage of missing values of spending_score_(1-100) less than limit 90 %, so we will keep it.
# New shape after missing value control: (200, 5)

# %%
df.head()
# Out:
#    customerid  gender  age  annual_income_(k$)  spending_score_(1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      customerid  gender  age  annual_income_(k$)  spending_score_(1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.sample(5)
# Out:
#      customerid  gender  age  annual_income_(k$)  spending_score_(1-100)
# 171         172    Male   28                  87                      75
# 127         128    Male   40                  71                      95
# 174         175  Female   52                  88                      13
# 146         147    Male   48                  77                      36
# 65           66    Male   18                  48                      59

# %%
df.describe().T
# Out:
#                          count    mean    std    min    25%     50%     75%  \
# customerid             200.000 100.500 57.879  1.000 50.750 100.500 150.250
# age                    200.000  38.850 13.969 18.000 28.750  36.000  49.000
# annual_income_(k$)     200.000  60.560 26.265 15.000 41.500  61.500  78.000
# spending_score_(1-100) 200.000  50.200 25.824  1.000 34.750  50.000  73.000
#
#                            max
# customerid             200.000
# age                     70.000
# annual_income_(k$)     137.000
# spending_score_(1-100)  99.000

# %%
df.describe(include=object).T
# Out:
#        count unique     top freq
# gender   200      2  Female  112

# %%
# to find how many unique values object features have
for col in df.select_dtypes(include=[np.number]).columns:
    print(f"{col} has {df[col].nunique()} unique value")
# Out:
# customerid has 200 unique value
# age has 51 unique value
# annual_income_(k$) has 64 unique value
# spending_score_(1-100) has 84 unique value

# %%
drop_columns(df,'customerid')
df
# Out:
# customerid were dropped
#      gender  age  annual_income_(k$)  spending_score_(1-100)
# 0      Male   19                  15                      39
# 1      Male   21                  15                      81
# 2    Female   20                  16                       6
# 3    Female   23                  16                      77
# 4    Female   31                  17                      40
# 5    Female   22                  17                      76
# 6    Female   35                  18                       6
# 7    Female   23                  18                      94
# 8      Male   64                  19                       3
# 9    Female   30                  19                      72
# 10     Male   67                  19                      14
# 11   Female   35                  19                      99
# 12   Female   58                  20                      15
# 13   Female   24                  20                      77
# 14     Male   37                  20                      13
# 15     Male   22                  20                      79
# 16   Female   35                  21                      35
# 17     Male   20                  21                      66
# 18     Male   52                  23                      29
# 19   Female   35                  23                      98
# 20     Male   35                  24                      35
# 21     Male   25                  24                      73
# 22   Female   46                  25                       5
# 23     Male   31                  25                      73
# 24   Female   54                  28                      14
# 25     Male   29                  28                      82
# 26   Female   45                  28                      32
# 27     Male   35                  28                      61
# 28   Female   40                  29                      31
# 29   Female   23                  29                      87
# 30     Male   60                  30                       4
# 31   Female   21                  30                      73
# 32     Male   53                  33                       4
# 33     Male   18                  33                      92
# 34   Female   49                  33                      14
# 35   Female   21                  33                      81
# 36   Female   42                  34                      17
# 37   Female   30                  34                      73
# 38   Female   36                  37                      26
# 39   Female   20                  37                      75
# 40   Female   65                  38                      35
# 41     Male   24                  38                      92
# 42     Male   48                  39                      36
# 43   Female   31                  39                      61
# 44   Female   49                  39                      28
# 45   Female   24                  39                      65
# 46   Female   50                  40                      55
# 47   Female   27                  40                      47
# 48   Female   29                  40                      42
# 49   Female   31                  40                      42
# 50   Female   49                  42                      52
# 51     Male   33                  42                      60
# 52   Female   31                  43                      54
# 53     Male   59                  43                      60
# 54   Female   50                  43                      45
# 55     Male   47                  43                      41
# 56   Female   51                  44                      50
# 57     Male   69                  44                      46
# 58   Female   27                  46                      51
# 59     Male   53                  46                      46
# 60     Male   70                  46                      56
# 61     Male   19                  46                      55
# 62   Female   67                  47                      52
# 63   Female   54                  47                      59
# 64     Male   63                  48                      51
# 65     Male   18                  48                      59
# 66   Female   43                  48                      50
# 67   Female   68                  48                      48
# 68     Male   19                  48                      59
# 69   Female   32                  48                      47
# 70     Male   70                  49                      55
# 71   Female   47                  49                      42
# 72   Female   60                  50                      49
# 73   Female   60                  50                      56
# 74     Male   59                  54                      47
# 75     Male   26                  54                      54
# 76   Female   45                  54                      53
# 77     Male   40                  54                      48
# 78   Female   23                  54                      52
# 79   Female   49                  54                      42
# 80     Male   57                  54                      51
# 81     Male   38                  54                      55
# 82     Male   67                  54                      41
# 83   Female   46                  54                      44
# 84   Female   21                  54                      57
# 85     Male   48                  54                      46
# 86   Female   55                  57                      58
# 87   Female   22                  57                      55
# 88   Female   34                  58                      60
# 89   Female   50                  58                      46
# 90   Female   68                  59                      55
# 91     Male   18                  59                      41
# 92     Male   48                  60                      49
# 93   Female   40                  60                      40
# 94   Female   32                  60                      42
# 95     Male   24                  60                      52
# 96   Female   47                  60                      47
# 97   Female   27                  60                      50
# 98     Male   48                  61                      42
# 99     Male   20                  61                      49
# 100  Female   23                  62                      41
# 101  Female   49                  62                      48
# 102    Male   67                  62                      59
# 103    Male   26                  62                      55
# 104    Male   49                  62                      56
# 105  Female   21                  62                      42
# 106  Female   66                  63                      50
# 107    Male   54                  63                      46
# 108    Male   68                  63                      43
# 109    Male   66                  63                      48
# 110    Male   65                  63                      52
# 111  Female   19                  63                      54
# 112  Female   38                  64                      42
# 113    Male   19                  64                      46
# 114  Female   18                  65                      48
# 115  Female   19                  65                      50
# 116  Female   63                  65                      43
# 117  Female   49                  65                      59
# 118  Female   51                  67                      43
# 119  Female   50                  67                      57
# 120    Male   27                  67                      56
# 121  Female   38                  67                      40
# 122  Female   40                  69                      58
# 123    Male   39                  69                      91
# 124  Female   23                  70                      29
# 125  Female   31                  70                      77
# 126    Male   43                  71                      35
# 127    Male   40                  71                      95
# 128    Male   59                  71                      11
# 129    Male   38                  71                      75
# 130    Male   47                  71                       9
# 131    Male   39                  71                      75
# 132  Female   25                  72                      34
# 133  Female   31                  72                      71
# 134    Male   20                  73                       5
# 135  Female   29                  73                      88
# 136  Female   44                  73                       7
# 137    Male   32                  73                      73
# 138    Male   19                  74                      10
# 139  Female   35                  74                      72
# 140  Female   57                  75                       5
# 141    Male   32                  75                      93
# 142  Female   28                  76                      40
# 143  Female   32                  76                      87
# 144    Male   25                  77                      12
# 145    Male   28                  77                      97
# 146    Male   48                  77                      36
# 147  Female   32                  77                      74
# 148  Female   34                  78                      22
# 149    Male   34                  78                      90
# 150    Male   43                  78                      17
# 151    Male   39                  78                      88
# 152  Female   44                  78                      20
# 153  Female   38                  78                      76
# 154  Female   47                  78                      16
# 155  Female   27                  78                      89
# 156    Male   37                  78                       1
# 157  Female   30                  78                      78
# 158    Male   34                  78                       1
# 159  Female   30                  78                      73
# 160  Female   56                  79                      35
# 161  Female   29                  79                      83
# 162    Male   19                  81                       5
# 163  Female   31                  81                      93
# 164    Male   50                  85                      26
# 165  Female   36                  85                      75
# 166    Male   42                  86                      20
# 167  Female   33                  86                      95
# 168  Female   36                  87                      27
# 169    Male   32                  87                      63
# 170    Male   40                  87                      13
# 171    Male   28                  87                      75
# 172    Male   36                  87                      10
# 173    Male   36                  87                      92
# 174  Female   52                  88                      13
# 175  Female   30                  88                      86
# 176    Male   58                  88                      15
# 177    Male   27                  88                      69
# 178    Male   59                  93                      14
# 179    Male   35                  93                      90
# 180  Female   37                  97                      32
# 181  Female   32                  97                      86
# 182    Male   46                  98                      15
# 183  Female   29                  98                      88
# 184  Female   41                  99                      39
# 185    Male   30                  99                      97
# 186  Female   54                 101                      24
# 187    Male   28                 101                      68
# 188  Female   41                 103                      17
# 189  Female   36                 103                      85
# 190  Female   34                 103                      23
# 191  Female   32                 103                      69
# 192    Male   33                 113                       8
# 193  Female   38                 113                      91
# 194  Female   47                 120                      16
# 195  Female   35                 120                      79
# 196  Female   45                 126                      28
# 197    Male   32                 126                      74
# 198    Male   32                 137                      18
# 199    Male   30                 137                      83

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)
#
# After performing Cluster Analysis, you need to know the data well in order to label the observations correctly. Analyze frequency distributions of features, relationships and correlations between the independent variables and the dependent variable. It is recommended to apply data visualization techniques. Observing breakpoints helps you to internalize the data.

# %%
df.columns
# Out:
# Index(['gender', 'age', 'annual_income_(k$)', 'spending_score_(1-100)'], dtype='object')

# %%
# 3-Target Examination
target = "gender"

print(colored('-'*79, 'red', attrs=['bold']), '\n',
      colored(f"Target(y):", attrs=['bold']), target, 
      colored(f"\nValue Counts:\n", attrs=['underline']), df[target].value_counts(),'\n',
      colored('-'*79, 'red', attrs=['bold']), sep='')

X_columns = df.drop(target, axis=1).columns
X_numerical = df.drop(target, axis=1).select_dtypes('number').astype('float64')
X_categorical = df.drop(target, axis=1).select_dtypes('object')

print(colored(f"Feature Columns:", attrs=['bold']), list(X_columns),'\n',
      colored('-'*79, 'red', attrs=['bold']), sep='')
print(colored(f"Numerical Columns:", attrs=['bold']), list(X_numerical.columns), '\n',
      colored('-'*79, 'red', attrs=['bold']), sep='')
print(colored(f"Categorical Columns:", attrs=['bold']), list(X_categorical.columns), '\n',
      colored('-'*79, 'red', attrs=['bold']), sep='')
print(colored(f"Number of Uniques:", attrs=['bold']), '\n', X_categorical.nunique(), '\n',
      colored('-'*79, 'red', attrs=['bold']), sep='')

# X_categorical.columns
# Out:
# -------------------------------------------------------------------------------
# Target(y):gender
# Value Counts:
# Female    112
# Male       88
# Name: gender, dtype: int64
# -------------------------------------------------------------------------------
# Feature Columns:['age', 'annual_income_(k$)', 'spending_score_(1-100)']
# -------------------------------------------------------------------------------
# Numerical Columns:['age', 'annual_income_(k$)', 'spending_score_(1-100)']
# -------------------------------------------------------------------------------
# Categorical Columns:[]
# -------------------------------------------------------------------------------
# Number of Uniques:
# Series([], dtype: float64)
# -------------------------------------------------------------------------------

# %%
sns.pairplot(df, palette="inferno", hue="gender", corner=True);
# Out:
# <img src="data:image/png;base64,..." width="612">

# %%
sns.pairplot(df, palette="inferno", hue="annual_income_(k$)", corner=True);
# Out:
# <img src="data:image/png;base64,..." width="468">

# %%
sns.pairplot(df, palette="inferno", hue="spending_score_(1-100)", corner=True);
# Out:
# <img src="data:image/png;base64,..." width="487.2">

# %%
fig = px.scatter_3d(df, 
                    x="annual_income_(k$)",
                    y="spending_score_(1-100)",
                    z="age",
                    color='gender')
fig.show();
# Out:
# <div>                            <div id="69be7ce7-f1a9-431b-a469-8525ee82da88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69be7ce7-f1a9-431b-a469-8525ee82da88")) {                    Plotly.newPlot(                        "69be7ce7-f1a9-431b-a469-8525ee82da88",                        [{"hovertemplate":"gender=Male<br>annual_income_(k$)=%{x}<br>spending_score_(1-100)=%{y}<br>age=%{z}<extra></extra>","legendgroup":"Male","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Male","scene":"scene","showlegend":true,"type":"scatter3d","x":[15,15,19,19,20,20,21,23,24,24,25,28,28,30,33,33,38,39,42,43,43,44,46,46,46,48,48,48,49,54,54,54,54,54,54,54,59,60,60,61,61,62,62,62,63,63,63,63,64,67,69,71,71,71,71,71,71,73,73,74,75,77,77,77,78,78,78,78,78,81,85,86,87,87,87,87,87,88,88,93,93,98,99,101,113,126,137,137],"y":[39,81,3,14,13,79,66,29,35,73,73,82,61,4,4,92,92,36,60,60,41,46,46,56,55,51,59,59,55,47,54,48,51,55,41,46,41,49,52,42,49,59,55,56,46,43,48,52,46,56,91,35,95,11,75,9,75,5,73,10,93,12,97,36,90,17,88,1,1,5,26,20,63,13,75,10,92,15,69,14,90,15,97,68,8,74,18,83],"z":[19,21,64,67,37,22,20,52,35,25,31,29,35,60,53,18,24,48,33,59,47,69,53,70,19,63,18,19,70,59,26,40,57,38,67,48,18,48,24,48,20,67,26,49,54,68,66,65,19,27,39,43,40,59,38,47,39,20,32,19,32,25,28,48,34,43,39,37,34,19,50,42,32,40,28,36,36,58,27,59,35,46,30,28,33,32,32,30]},{"hovertemplate":"gender=Female<br>annual_income_(k$)=%{x}<br>spending_score_(1-100)=%{y}<br>age=%{z}<extra></extra>","legendgroup":"Female","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Female","scene":"scene","showlegend":true,"type":"scatter3d","x":[16,16,17,17,18,18,19,19,20,20,21,23,25,28,28,29,29,30,33,33,34,34,37,37,38,39,39,39,40,40,40,40,42,43,43,44,46,47,47,48,48,48,49,50,50,54,54,54,54,54,57,57,58,58,59,60,60,60,60,62,62,62,63,63,64,65,65,65,65,67,67,67,69,70,70,72,72,73,73,74,75,76,76,77,78,78,78,78,78,78,78,79,79,81,85,86,87,88,88,97,97,98,99,101,103,103,103,103,113,120,120,126],"y":[6,77,40,76,6,94,72,99,15,77,35,98,5,14,32,31,87,73,14,81,17,73,26,75,35,61,28,65,55,47,42,42,52,54,45,50,51,52,59,50,48,47,42,49,56,53,52,42,44,57,58,55,60,46,55,40,42,47,50,41,48,42,50,54,42,48,50,43,59,43,57,40,58,29,77,34,71,88,7,72,5,40,87,74,22,20,76,16,89,78,73,35,83,93,75,95,27,13,86,32,86,88,39,24,17,85,23,69,91,16,79,28],"z":[20,23,31,22,35,23,30,35,58,24,35,35,46,54,45,40,23,21,49,21,42,30,36,20,65,31,49,24,50,27,29,31,49,31,50,51,27,67,54,43,68,32,47,60,60,45,23,49,46,21,55,22,34,50,68,40,32,47,27,23,49,21,66,19,38,18,19,63,49,51,50,38,40,23,31,25,31,29,44,35,57,28,32,32,34,44,38,47,27,30,30,56,29,31,36,33,36,52,30,37,32,29,41,54,41,36,34,32,38,47,35,45]}],                        {"legend":{"title":{"text":"gender"},"tracegroupgap":0},"margin":{"t":60},"scene":{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"xaxis":{"title":{"text":"annual_income_(k$)"}},"yaxis":{"title":{"text":"spending_score_(1-100)"}},"zaxis":{"title":{"text":"age"}}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111 ...

# %%
fig = px.histogram(df, x="annual_income_(k$)", color="age",width=400, height=400)
fig.show()
# Out:
# <div>                            <div id="4c5c4847-9c47-43d6-bd10-28b9c10756d7" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c5c4847-9c47-43d6-bd10-28b9c10756d7")) {                    Plotly.newPlot(                        "4c5c4847-9c47-43d6-bd10-28b9c10756d7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=19<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"19","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"19","offsetgroup":"19","orientation":"v","showlegend":true,"type":"histogram","x":[15,46,48,63,64,65,74,81],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=21<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"21","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"21","offsetgroup":"21","orientation":"v","showlegend":true,"type":"histogram","x":[15,30,33,54,62],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=20<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"20","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"20","offsetgroup":"20","orientation":"v","showlegend":true,"type":"histogram","x":[16,21,37,61,73],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=23<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"23","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"23","offsetgroup":"23","orientation":"v","showlegend":true,"type":"histogram","x":[16,18,29,54,62,70],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=31<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"31","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"31","offsetgroup":"31","orientation":"v","showlegend":true,"type":"histogram","x":[17,25,39,40,43,70,72,81],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=22<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"22","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"22","offsetgroup":"22","orientation":"v","showlegend":true,"type":"histogram","x":[17,20,57],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=35<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"35","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"35","offsetgroup":"35","orientation":"v","showlegend":true,"type":"histogram","x":[18,19,21,23,24,28,74,93,120],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=64<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"64","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"64","offsetgroup":"64","orientation":"v","showlegend":true,"type":"histogram","x":[19],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=30<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"30","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"30","offsetgroup":"30","orientation":"v","showlegend":true,"type":"histogram","x":[19,34,78,78,88,99,137],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=67<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"67","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"67","offsetgroup":"67","orientation":"v","showlegend":true,"type":"histogram","x":[19,47,54,62],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=58<br>annual_income_(k$)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"58","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"58","off ...

# %%
plt.figure(figsize=(10, 6))
fig = px.histogram(df, x="spending_score_(1-100)", color="age",width=400, height=400)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="720">
# <div>                            <div id="43eaa403-a6e7-4e57-8726-838288b3d32a" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43eaa403-a6e7-4e57-8726-838288b3d32a")) {                    Plotly.newPlot(                        "43eaa403-a6e7-4e57-8726-838288b3d32a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=19<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"19","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"19","offsetgroup":"19","orientation":"v","showlegend":true,"type":"histogram","x":[39,55,59,54,46,50,10,5],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=21<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"21","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"21","offsetgroup":"21","orientation":"v","showlegend":true,"type":"histogram","x":[81,73,81,57,42],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=20<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"20","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"20","offsetgroup":"20","orientation":"v","showlegend":true,"type":"histogram","x":[6,66,75,49,5],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=23<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"23","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"23","offsetgroup":"23","orientation":"v","showlegend":true,"type":"histogram","x":[77,94,87,52,41,29],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=31<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"31","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"31","offsetgroup":"31","orientation":"v","showlegend":true,"type":"histogram","x":[40,73,61,42,54,77,71,93],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=22<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"22","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"22","offsetgroup":"22","orientation":"v","showlegend":true,"type":"histogram","x":[76,79,55],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=35<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"35","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"35","offsetgroup":"35","orientation":"v","showlegend":true,"type":"histogram","x":[6,99,35,98,35,61,72,90,79],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=64<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"64","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"64","offsetgroup":"64","orientation":"v","showlegend":true,"type":"histogram","x":[3],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=30<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"30","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"30","offsetgroup":"30","orientation":"v","showlegend":true,"type":"histogram","x":[72,73,78,73,86,97,83],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=67<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"67","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"67","offsetgroup":"67","orientation":"v","showlegend":true,"type":"histogram","x":[14,52,41,59],"xaxis":"x","yaxis":"y"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=58<br>spending_score_(1-100)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"58","marker":{"color":"#636efa","pa ...

# %%
sns.barplot(y = "annual_income_(k$)", x = df.index, data = df);

# %%
sns.barplot(y = "spending_score_(1-100)", x = df.index, data = df);

# %%
X_numerical.iplot(kind='histogram',subplots=True,bins=50)
# Out:
# <div>                            <div id="786d057b-859d-4d56-a5fb-59c9348cf703" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("786d057b-859d-4d56-a5fb-59c9348cf703")) {                    Plotly.newPlot(                        "786d057b-859d-4d56-a5fb-59c9348cf703",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"age","nbinsx":50,"opacity":0.8,"orientation":"v","type":"histogram","x":[19.0,21.0,20.0,23.0,31.0,22.0,35.0,23.0,64.0,30.0,67.0,35.0,58.0,24.0,37.0,22.0,35.0,20.0,52.0,35.0,35.0,25.0,46.0,31.0,54.0,29.0,45.0,35.0,40.0,23.0,60.0,21.0,53.0,18.0,49.0,21.0,42.0,30.0,36.0,20.0,65.0,24.0,48.0,31.0,49.0,24.0,50.0,27.0,29.0,31.0,49.0,33.0,31.0,59.0,50.0,47.0,51.0,69.0,27.0,53.0,70.0,19.0,67.0,54.0,63.0,18.0,43.0,68.0,19.0,32.0,70.0,47.0,60.0,60.0,59.0,26.0,45.0,40.0,23.0,49.0,57.0,38.0,67.0,46.0,21.0,48.0,55.0,22.0,34.0,50.0,68.0,18.0,48.0,40.0,32.0,24.0,47.0,27.0,48.0,20.0,23.0,49.0,67.0,26.0,49.0,21.0,66.0,54.0,68.0,66.0,65.0,19.0,38.0,19.0,18.0,19.0,63.0,49.0,51.0,50.0,27.0,38.0,40.0,39.0,23.0,31.0,43.0,40.0,59.0,38.0,47.0,39.0,25.0,31.0,20.0,29.0,44.0,32.0,19.0,35.0,57.0,32.0,28.0,32.0,25.0,28.0,48.0,32.0,34.0,34.0,43.0,39.0,44.0,38.0,47.0,27.0,37.0,30.0,34.0,30.0,56.0,29.0,19.0,31.0,50.0,36.0,42.0,33.0,36.0,32.0,40.0,28.0,36.0,36.0,52.0,30.0,58.0,27.0,59.0,35.0,37.0,32.0,46.0,29.0,41.0,30.0,54.0,28.0,41.0,36.0,34.0,32.0,33.0,38.0,47.0,35.0,45.0,32.0,32.0,30.0],"xaxis":"x","yaxis":"y"},{"histfunc":"count","histnorm":"","marker":{"color":"rgba(55, 128, 191, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"annual_income_(k$)","nbinsx":50,"opacity":0.8,"orientation":"v","type":"histogram","x":[15.0,15.0,16.0,16.0,17.0,17.0,18.0,18.0,19.0,19.0,19.0,19.0,20.0,20.0,20.0,20.0,21.0,21.0,23.0,23.0,24.0,24.0,25.0,25.0,28.0,28.0,28.0,28.0,29.0,29.0,30.0,30.0,33.0,33.0,33.0,33.0,34.0,34.0,37.0,37.0,38.0,38.0,39.0,39.0,39.0,39.0,40.0,40.0,40.0,40.0,42.0,42.0,43.0,43.0,43.0,43.0,44.0,44.0,46.0,46.0,46.0,46.0,47.0,47.0,48.0,48.0,48.0,48.0,48.0,48.0,49.0,49.0,50.0,50.0,54.0,54.0,54.0,54.0,54.0,54.0,54.0,54.0,54.0,54.0,54.0,54.0,57.0,57.0,58.0,58.0,59.0,59.0,60.0,60.0,60.0,60.0,60.0,60.0,61.0,61.0,62.0,62.0,62.0,62.0,62.0,62.0,63.0,63.0,63.0,63.0,63.0,63.0,64.0,64.0,65.0,65.0,65.0,65.0,67.0,67.0,67.0,67.0,69.0,69.0,70.0,70.0,71.0,71.0,71.0,71.0,71.0,71.0,72.0,72.0,73.0,73.0,73.0,73.0,74.0,74.0,75.0,75.0,76.0,76.0,77.0,77.0,77.0,77.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,79.0,79.0,81.0,81.0,85.0,85.0,86.0,86.0,87.0,87.0,87.0,87.0,87.0,87.0,88.0,88.0,88.0,88.0,93.0,93.0,97.0,97.0,98.0,98.0,99.0,99.0,101.0,101.0,103.0,103.0,103.0,103.0,113.0,113.0,120.0,120.0,126.0,126.0,137.0,137.0],"xaxis":"x2","yaxis":"y2"},{"histfunc":"count","histnorm":"","marker":{"color":"rgba(50, 171, 96, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"spending_score_(1-100)","nbinsx":50,"opacity":0.8,"orientation":"v","type":"histogram","x":[39.0,81.0,6.0,77.0,40.0,76.0,6.0,94.0,3.0,72.0,14.0,99.0,15.0,77.0,13.0,79.0,35.0,66.0,29.0,98.0,35.0,73.0,5.0,73.0,14.0,82.0,32.0,61.0,31.0,87.0,4.0,73.0,4.0,92.0,14.0,81.0,17.0,73.0,26.0,75.0,35.0,92.0,36.0,61.0,28.0,65.0,55.0,47.0,42.0,42.0,52.0,60.0,54.0,60.0,45.0,41.0,50.0,46.0,51.0,46.0,56.0,55.0,52.0,59.0,51.0,59.0,50.0,48.0,59.0,47.0,55.0,42.0,49.0,56.0,47.0,54.0,53.0,48.0,52.0,42.0,51.0,55.0,41.0,44.0,57.0,46.0,58.0,55.0,60.0,46.0,55.0,41.0,49.0,40.0,42.0,52.0,47.0,50.0,42.0,49.0,41.0,48.0,59.0,55.0,56.0,42.0,50.0,46.0,43.0,48.0,52.0,54.0,42.0,46.0,48.0,50.0,43.0,59.0,43.0,57.0,56.0,40.0,58.0,91.0,29.0,77.0,35.0,95.0,11.0,75.0,9.0,75.0,34.0,71.0,5.0,88.0,7.0,73.0,10.0,72.0,5.0,93.0,40.0,87.0,12.0,97.0,36.0,74.0,22.0,90.0,17.0,88.0,20.0,76.0,16.0,89.0,1.0,78.0,1.0,73.0,35.0,83.0,5.0,93.0,26.0,75.0,20.0,95.0,27.0,63.0,13.0,75.0,10.0,92.0,13.0,86.0,15.0,69.0,14.0,90.0,32.0,86.0,15.0,88.0,39.0,97.0,24.0,68.0,17.0,85.0,23.0,69.0,8.0,91.0,16.0,79.0,28.0,74.0,18.0,83.0],"xaxis":"x3","yaxis":" ...

# %%
for i in df.drop(columns=[target]).columns:
    df[i].iplot(kind="box", title=i, boxpoints="all", color='lightseagreen')
# Out:
# <div>                            <div id="249c4558-89b8-4a53-91f3-426e5aa99cfe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("249c4558-89b8-4a53-91f3-426e5aa99cfe")) {                    Plotly.newPlot(                        "249c4558-89b8-4a53-91f3-426e5aa99cfe",                        [{"boxpoints":"all","line":{"width":1.3},"marker":{"color":"rgba(32, 178, 170, 1.0)"},"name":"age","orientation":"v","type":"box","y":[19,21,20,23,31,22,35,23,64,30,67,35,58,24,37,22,35,20,52,35,35,25,46,31,54,29,45,35,40,23,60,21,53,18,49,21,42,30,36,20,65,24,48,31,49,24,50,27,29,31,49,33,31,59,50,47,51,69,27,53,70,19,67,54,63,18,43,68,19,32,70,47,60,60,59,26,45,40,23,49,57,38,67,46,21,48,55,22,34,50,68,18,48,40,32,24,47,27,48,20,23,49,67,26,49,21,66,54,68,66,65,19,38,19,18,19,63,49,51,50,27,38,40,39,23,31,43,40,59,38,47,39,25,31,20,29,44,32,19,35,57,32,28,32,25,28,48,32,34,34,43,39,44,38,47,27,37,30,34,30,56,29,19,31,50,36,42,33,36,32,40,28,36,36,52,30,58,27,59,35,37,32,46,29,41,30,54,28,41,36,34,32,33,38,47,35,45,32,32,30]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d ...
# <div>                            <div id="f527fa7f-be81-4089-91f7-87f9d5f89dd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("f527fa7f-be81-4089-91f7-87f9d5f89dd0")) {                    Plotly.newPlot(                        "f527fa7f-be81-4089-91f7-87f9d5f89dd0",                        [{"boxpoints":"all","line":{"width":1.3},"marker":{"color":"rgba(32, 178, 170, 1.0)"},"name":"annual_income_(k$)","orientation":"v","type":"box","y":[15,15,16,16,17,17,18,18,19,19,19,19,20,20,20,20,21,21,23,23,24,24,25,25,28,28,28,28,29,29,30,30,33,33,33,33,34,34,37,37,38,38,39,39,39,39,40,40,40,40,42,42,43,43,43,43,44,44,46,46,46,46,47,47,48,48,48,48,48,48,49,49,50,50,54,54,54,54,54,54,54,54,54,54,54,54,57,57,58,58,59,59,60,60,60,60,60,60,61,61,62,62,62,62,62,62,63,63,63,63,63,63,64,64,65,65,65,65,67,67,67,67,69,69,70,70,71,71,71,71,71,71,72,72,73,73,73,73,74,74,75,75,76,76,77,77,77,77,78,78,78,78,78,78,78,78,78,78,78,78,79,79,81,81,85,85,86,86,87,87,87,87,87,87,88,88,88,88,93,93,97,97,98,98,99,99,101,101,103,103,103,103,113,113,120,120,126,126,137,137]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth" ...
# <div>                            <div id="f636649d-1826-4e67-907e-96d590471be7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("f636649d-1826-4e67-907e-96d590471be7")) {                    Plotly.newPlot(                        "f636649d-1826-4e67-907e-96d590471be7",                        [{"boxpoints":"all","line":{"width":1.3},"marker":{"color":"rgba(32, 178, 170, 1.0)"},"name":"spending_score_(1-100)","orientation":"v","type":"box","y":[39,81,6,77,40,76,6,94,3,72,14,99,15,77,13,79,35,66,29,98,35,73,5,73,14,82,32,61,31,87,4,73,4,92,14,81,17,73,26,75,35,92,36,61,28,65,55,47,42,42,52,60,54,60,45,41,50,46,51,46,56,55,52,59,51,59,50,48,59,47,55,42,49,56,47,54,53,48,52,42,51,55,41,44,57,46,58,55,60,46,55,41,49,40,42,52,47,50,42,49,41,48,59,55,56,42,50,46,43,48,52,54,42,46,48,50,43,59,43,57,56,40,58,91,29,77,35,95,11,75,9,75,34,71,5,88,7,73,10,72,5,93,40,87,12,97,36,74,22,90,17,88,20,76,16,89,1,78,1,73,35,83,5,93,26,75,20,95,27,63,13,75,10,92,13,86,15,69,14,90,32,86,15,88,39,97,24,68,17,85,23,69,8,91,16,79,28,74,18,83]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"m ...

# %%
index = 0
plt.figure(figsize=(16, 8))
for feature in df.columns:
    if feature != target:
        index += 1
        plt.subplot(1, 3, index)
        sns.boxplot(x=target, y=feature, data=df)
# Out:
# <img src="data:image/png;base64,..." width="1152">

# %%
for column in df:
        plt.figure(figsize=(20, 8))
        sns.boxplot(data=df, x=column, y="annual_income_(k$)");
# Out:
# <img src="data:image/png;base64,..." width="1440">
# <img src="data:image/png;base64,..." width="1440">
# <img src="data:image/png;base64,..." width="1440">
# <img src="data:image/png;base64,..." width="1440">

# %%
df.corr().style.background_gradient(cmap='RdPu')
# Out:
# <style type="text/css">
# #T_bd473_row0_col0, #T_bd473_row1_col1, #T_bd473_row2_col2 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_bd473_row0_col1, #T_bd473_row0_col2, #T_bd473_row2_col0 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_bd473_row1_col0 {
#   background-color: #fcc8c3;
#   color: #000000;
# }
# #T_bd473_row1_col2 {
#   background-color: #fcc4c0;
#   color: #000000;
# }
# #T_bd473_row2_col1 {
#   background-color: #fff3f0;
#   color: #000000;
# }
# </style>
# <table id="T_bd473_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >annual_income_(k$)</th>
#       <th class="col_heading level0 col2" >spending_score_(1-100)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd473_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_bd473_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bd473_row0_col1" class="data row0 col1" >-0.012398</td>
#       <td id="T_bd473_row0_col2" class="data row0 col2" >-0.327227</td>
#     </tr>
#     <tr>
#       <th id="T_bd473_level0_row1" class="row_heading level0 row1" >annual_income_(k$)</th>
#       <td id="T_bd473_row1_col0" class="data row1 col0" >-0.012398</td>
#       <td id="T_bd473_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bd473_row1_col2" class="data row1 col2" >0.009903</td>
#     </tr>
#     <tr>
#       <th id="T_bd473_level0_row2" class="row_heading level0 row2" >spending_score_(1-100)</th>
#       <td id="T_bd473_row2_col0" class="data row2 col0" >-0.327227</td>
#       <td id="T_bd473_row2_col1" class="data row2 col1" >0.009903</td>
#       <td id="T_bd473_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
X_numerical.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_c302e_row0_col0, #T_c302e_row0_col1, #T_c302e_row0_col2, #T_c302e_row0_col5, #T_c302e_row1_col0, #T_c302e_row2_col0 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_c302e_row1_col1, #T_c302e_row1_col2, #T_c302e_row1_col5 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_c302e_row2_col1 {
#   background-color: #f35f9f;
#   color: #f1f1f1;
# }
# #T_c302e_row2_col2 {
#   background-color: #57006e;
#   color: #f1f1f1;
# }
# #T_c302e_row2_col5 {
#   background-color: #ed549d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c302e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c302e_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_c302e_row0_col0" class="data row0 col0" >200.000000</td>
#       <td id="T_c302e_row0_col1" class="data row0 col1" >38.850000</td>
#       <td id="T_c302e_row0_col2" class="data row0 col2" >13.969007</td>
#       <td id="T_c302e_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_c302e_row0_col4" class="data row0 col4" >28.750000</td>
#       <td id="T_c302e_row0_col5" class="data row0 col5" >36.000000</td>
#       <td id="T_c302e_row0_col6" class="data row0 col6" >49.000000</td>
#       <td id="T_c302e_row0_col7" class="data row0 col7" >70.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c302e_level0_row1" class="row_heading level0 row1" >annual_income_(k$)</th>
#       <td id="T_c302e_row1_col0" class="data row1 col0" >200.000000</td>
#       <td id="T_c302e_row1_col1" class="data row1 col1" >60.560000</td>
#       <td id="T_c302e_row1_col2" class="data row1 col2" >26.264721</td>
#       <td id="T_c302e_row1_col3" class="data row1 col3" >15.000000</td>
#       <td id="T_c302e_row1_col4" class="data row1 col4" >41.500000</td>
#       <td id="T_c302e_row1_col5" class="data row1 col5" >61.500000</td>
#       <td id="T_c302e_row1_col6" class="data row1 col6" >78.000000</td>
#       <td id="T_c302e_row1_col7" class="data row1 col7" >137.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c302e_level0_row2" class="row_heading level0 row2" >spending_score_(1-100)</th>
#       <td id="T_c302e_row2_col0" class="data row2 col0" >200.000000</td>
#       <td id="T_c302e_row2_col1" class="data row2 col1" >50.200000</td>
#       <td id="T_c302e_row2_col2" class="data row2 col2" >25.823522</td>
#       <td id="T_c302e_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_c302e_row2_col4" class="data row2 col4" >34.750000</td>
#       <td id="T_c302e_row2_col5" class="data row2 col5" >50.000000</td>
#       <td id="T_c302e_row2_col6" class="data row2 col6" >73.000000</td>
#       <td id="T_c302e_row2_col7" class="data row2 col7" >99.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
skew_limit = 0.75 # This is our threshold-limit to evaluate skewness. Overall below abs(1) seems acceptable for the linear models. 
skew_vals = X_numerical.skew()
skew_cols= skew_vals[abs(skew_vals)> skew_limit].sort_values(ascending=False)
skew_cols
# Out:
# Series([], dtype: float64)

# %%
df.groupby("age")['annual_income_(k$)'].mean().sort_values(ascending=False).nlargest(10)
# Out:
# age
# 41   101.000
# 32    87.182
# 28    85.250
# 36    81.000
# 33    80.333
# 56    79.000
# 34    79.000
# 30    76.143
# 44    75.500
# 38    74.500
# Name: annual_income_(k$), dtype: float64

# %%
df.groupby("age")['spending_score_(1-100)'].mean().sort_values(ascending=False).nlargest(10)
# Out:
# age
# 39   84.667
# 30   80.286
# 29   76.600
# 24   71.500
# 22   70.000
# 28   70.000
# 21   66.800
# 32   66.000
# 35   63.889
# 31   63.875
# Name: spending_score_(1-100), dtype: float64

# %% [markdown]
# ## 3. Cluster Analysis

# %% [markdown]
# The main purpose of this project is to perform [cluster analysis](https://en.wikipedia.org/wiki/Cluster_analysis#:~:text=Cluster%20analysis%20or%20clustering%20is,in%20other%20groups%20(clusters).) with the [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) algorithm.
#
# You can perform many [cluster analysis](http://www.stat.columbia.edu/~madigan/W2025/notes/clustering.pdf) using different variables. If you use a maximum of two variables for each cluster analysis, you can identify cluster labels more clearly.
#
# First, the K-Means algorithm expects you to determine the number of clusters (*n_clusters*). You can determine the optimal number of clusters for each cluster analysis in various ways. In this case, you are expected to use the [Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering).
#
# Finally, different information is obtained in each analysis. Therefore, different labeling should be done as a result of each cluster analysis.
#
# Labeling example:
#
# - **Normal Customers**  -- An Average consumer in terms of spending and Annual Income
# - **Spender Customers** --  Annual Income is less but spending high, so can also be treated as potential target customer.

# %% [markdown]
# ### Clustering based on Age and Spending Score

# %% [markdown]
# #### *i. Create a new dataset with two variables of your choice*

# %% [markdown]
# #### *ii. Determine optimal number of clusters*

# %% [markdown]
# #### *iii. Apply K Means*

# %% [markdown]
# #### *iv. Visualizing and Labeling All the Clusters*

# %% [markdown]
# ### Clustering based on Annual Income and Spending Score

# %% [markdown]
# #### *i. Create a new dataset with two variables of your choice*

# %% [markdown]
# #### *ii. Determine optimal number of clusters*

# %% [markdown]
# #### *iii. Apply K Means*

# %% [markdown]
# #### *iv. Visualizing and Labeling All the Clusters*

# %% [markdown]
# ### Hierarchical Clustering

# %% [markdown]
# #### *i. Determine optimal number of clusters using Dendogram*

# %% [markdown]
# #### ii. *Apply Agglomerative Clustering*

# %% [markdown]
# #### iii. *Visualizing and Labeling All the Clusters*

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
